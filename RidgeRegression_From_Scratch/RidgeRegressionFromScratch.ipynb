# %%
import numpy as np
from sklearn.metrics import r2_score
from sklearn.datasets import fetch_california_housing
from sklearn.linear_model import Ridge

# %%
from os import altsep
class RidgeRegression:
  def __init__(self,alpha=1.0):
    self.coef_ = None
    self.intercept_ = 0.0
    self.alpha = alpha
  def fit(self,X,y):
    x = np.array(X)
    y = np.array(y)
    Xb = np.c_[np.ones((X.shape[0],1)),X]
    penalty_dim = Xb.shape[1]
    I = np.eye(penalty_dim)
    I[0,0]=0.0
    A = np.linalg.inv(Xb.T @ Xb + self.alpha*I) @ Xb.T @ y
    self.intercept_ = A[0]
    self.coef_ = A[1:]

  def predict(self,X):
    return self.intercept_ + np.dot(X,self.coef_)


X,y = fetch_california_housing(return_X_y=True  )
reg  = RidgeRegression(alpha=2)
reg.fit(X,y)
y_predict = reg.predict(X)
print(r2_score(y,y_predict))
print(y_predict)
print(y-y_predict)
print(reg.coef_)

regsk  = Ridge(alpha=1)
regsk.fit(X,y)
y_predict = regsk.predict(X)
print(r2_score(y,y_predict))
# Out:
# 0.6062325794705161
# [4.13144352 3.9761872  3.6770052  ... 0.17152485 0.31928281 0.51587367]
# [ 0.39455648 -0.3911872  -0.1560052  ...  0.75147515  0.52771719
#   0.37812633]
# [ 4.36495800e-01  9.43901106e-03 -1.06944092e-01  6.43062429e-01
#  -3.96430115e-06 -3.78617577e-03 -4.21284056e-01 -4.34455530e-01]
# 0.6062326586911464
